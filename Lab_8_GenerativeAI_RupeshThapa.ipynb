# %% [markdown]
# <a href="https://colab.research.google.com/github/rupeshthapa123/NotebookProject/blob/main/Lab_8_GenerativeAI_RupeshThapa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generative AI

# %% [markdown]
# ## Text Generation in Keras
#
# First step is downloading the dataset and extracting it: the data contains wikipedia and other movie reviews

# %%
# !wget https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Out:
# --2024-07-27 22:40:01--  https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# Saving to: ‘aclImdb_v1.tar.gz’
#
# aclImdb_v1.tar.gz   100%[===================>]  80.23M  9.96MB/s    in 16s
#
# 2024-07-27 22:40:17 (5.17 MB/s) - ‘aclImdb_v1.tar.gz’ saved [84125825/84125825]

# %%
# !tar -xf aclImdb_v1.tar.gz

# %% [markdown]
# ## Importing all necessary library

# %%
import keras
import tensorflow
from tensorflow import keras
from tensorflow.keras import layers

# %%
import tensorflow as tf

dataset = keras.utils.text_dataset_from_directory(
    "aclImdb",
    label_mode=None,
    batch_size=256,
)
dataset = dataset.map(lambda x: tf.strings.regex_replace(x, "<br />", " "))
# Out:
# Found 100006 files belonging to 1 classes.

# %% [markdown]
# ## Using a Text Vectorization layer to compute the vocabulary
# Also, we consider the first sequence_length words of each review and cut the rest

# %%
from tensorflow.keras.layers import TextVectorization

sequence_length = 100
vocab_size = 15000
text_vectorization = TextVectorization(
    max_tokens=vocab_size,
    output_mode="int",
    output_sequence_length=sequence_length,
)
text_vectorization.adapt(dataset)

# %% [markdown]
# ## Using a TextVectorization layer to create a language modeling dataset

# %%
def prepare_lm_dataset(text_batch):
  vectorized_sequences = text_vectorization(text_batch)
  x = vectorized_sequences[:, :-1]
  y = vectorized_sequences[:, 1:]
  return x, y

lm_dataset = dataset.map(prepare_lm_dataset, num_parallel_calls=4)

# %% [markdown]
# ## Helper class for positional Embedding

# %%
class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, input_dim, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.token_embeddings = layers.Embedding(
            input_dim=input_dim, output_dim=output_dim
        )
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim
        )
        self.sequence_length = sequence_length
        self.input_dim = input_dim
        self.output_dim = output_dim

    def call(self, inputs):
      length = tf.shape(inputs)[-1]
      positions = tf.range(start=0, limit=length, delta=1)
      embedded_tokens = self.token_embeddings(inputs)
      embedded_positions = self.position_embeddings(positions)
      return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
      return tf.math.not_equal(inputs, 0)

    def get_config(self):
      config = super().get_config()
      config.update({
          "output_dim": self.output_dim,
          "sequence_length": self.sequence_length,
          "input_dim": self.input_dim
      })
      return config

# %% [markdown]
# ## Helper Class for Transformer Encoder

# %%
class TransformerEncoder(layers.Layer):
  def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
    super().__init__(**kwargs)
    self.embed_dim = embed_dim
    self.dense_dim = dense_dim
    self.num_heads = num_heads
    self.attention = layers.MultiHeadAttention(
        num_heads=num_heads, key_dim=embed_dim)
    self.dense_proj = keras.Sequential(
        [layers.Dense(dense_dim, activation="relu"),
        layers.Dense(embed_dim),]
    )
    self.layernorm_1 = layers.LayerNormalization()
    self.layernorm_2 = layers.LayerNormalization()

  def call(self, inputs, mask=None):
    if mask is not None:
      mask = mask[:, tf.newaxis, :]
    attention_output = self.attention(
        inputs, inputs, attention_mask=mask
    )
    proj_input = self.layernorm_1(inputs + attention_output)
    proj_output = self.dense_proj(proj_input)
    return self.layernorm_2(proj_input + proj_output)

  def get_config(self):
    config = super().get_config()
    config.update({
        "embed_dim": self.embed_dim,
        "num_heads": self.num_heads,
        "dense_dim": self.dense_dim
    })
    return config

# %% [markdown]
# ## Using a different softmax temperatures to see how the model converges

# %%
import numpy as np

tokens_index = dict(enumerate(text_vectorization.get_vocabulary()))

def sample_next(predictions, temperature=1.0):
  predictions = np.asarray(predictions).astype("float64")
  predictions = np.log(predictions) / temperature
  exp_preds = np.exp(predictions)
  predictions = exp_preds / np.sum(exp_preds)
  probas = np.random.multinomial(1, predictions, 1)
  return np.argmax(probas)

class TextGenerator(keras.callbacks.Callback):
  def __init__(self, prompt, generate_length, model_input_length, temperatures=(1.,), print_freq=1):
    self.prompt = prompt
    self.generate_length = generate_length
    self.model_input_length = model_input_length
    self.temperatures = temperatures
    self.print_freq = print_freq

  def on_epoch_end(self, epoch, logs=None):
    if (epoch + 1) % self.print_freq != 0:
      return
    for temperature in self.temperatures:
      print(f"== Generating with temperature", temperature)
      sentence = self.prompt
      for i in range(self.generate_length):
        tokenized_sentence = text_vectorization([sentence])
        predictions = self.model(tokenized_sentence)
        next_token = sample_next(predictions[0, i, :])
        sampled_token = tokens_index[next_token]
        sentence += " " + sampled_token
      print(sentence)

# %% [markdown]
# ### Creating the model

# %%
# Model definition
embed_dim = 256
dense_dim = 2048
num_heads = 2

inputs = keras.Input(shape=(None,), dtype="int64")
x = PositionalEmbedding(sequence_length, vocab_size, embed_dim)(inputs)
x = TransformerEncoder(embed_dim, dense_dim, num_heads)(x)
outputs = layers.Dense(vocab_size, activation="softmax")(x)
model = keras.Model(inputs, outputs)

# %%
model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer="rmsprop",
)

# %%
prompt = "This movie"
text_gen_callback = TextGenerator(
    prompt,
    generate_length=50,
    model_input_length=sequence_length,
    temperatures=(0.2, 0.5, 1.0, 1.5))

# %% [markdown]
# ## Training
# Final model can be trained and even though 200 epochs might be needed but here we are just using 50 epochs

# %%
model.fit(lm_dataset, epochs=50, callbacks=[text_gen_callback])
# Out:
# Epoch 1/50
# 391/391 [==============================] - ETA: 0s - loss: 5.6810== Generating with temperature 0.2
# This movie movie terrible ive movie ever  this movie it art you laugh
# == Generating with temperature 0.5
# This movie this this this awful this wrong movie watching unfortunately you  even bad into movies this movie this girl this movie but this thing this movie the people you just matter this porn movies to be high
# == Generating with temperature 1.0
# This movie movie line visually  this awful had cameos it
# == Generating with temperature 1.5
# This movie people this my movie live while graduate the i suspense love this if is it disappointed is its much slow has humour its  vote if you [UNK] 1972 this its just want you like me this frederic writing it dont just funny
# 391/391 [==============================] - 141s 352ms/step - loss: 5.6810
# Epoch 2/50
# 391/391 [==============================] - ETA: 0s - loss: 5.1674== Generating with temperature 0.2
# This movie movie watch movie this movie movie movie movie movie movie a movie movie movie this film movie is movie effort movie movie movie movie great really movie movie movie movie movie movie movie movie feel movie blood movie movie movie movie movie movie movie movie movie if movie movie movie
# == Generating with temperature 0.5
# This movie this did this this short this this  this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this
# == Generating with temperature 1.0
# This movie only delivers thing this this this movie this themselves this this even awful this this this this this this this this movie this this movie this this this this this this this this this this [UNK] this this this this this this this this this this this this this this
# == Generating with temperature 1.5
# This movie this this this  this this this this this this this worst this this this 10 this this this this this this this this this this this this arise this this this this this this this this this this this this this this this this this this this this this
# 391/391 [==============================] - 140s 357ms/step - loss: 5.1674
# Epoch 3/50
# 391/391 [==============================] - ETA: 0s - loss: 4.9685== Generating with temperature 0.2
# This movie short this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this
# == Generating with temperature 0.5
# This movie this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this
# == Generating with temperature 1.0
# This movie movie this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this
# == Generating with temperature 1.5
# This movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie
# 391/391 [==============================] - 140s 358ms/step - loss: 4.9685
# Epoch 4/50
# 391/391 [==============================] - ETA: 0s - loss: 4.8230== Generating with temperature 0.2
# This movie movie [UNK] this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this
# == Generating with temperature 0.5
# This movie movie its its first movie its its its its its its its its its its its its its its its its its its its its its its its its its its its its its its its its its its its its its its its its its its its its its
# == Generating with temperature 1.0
# This movie this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this
# == Generating with temperature 1.5
# This movie movie this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this
# 391/391 [==============================] - 140s 357ms/step - loss: 4.8230
# Epoch 5/50
# 391/391 [==============================] - ETA: 0s - loss: 4.7077== Generating with temperature 0.2
# This movie this this this this really this this this this this this this so this this this this is this this this this this this this this this this this this this this this this this this this this there truly this there this this this this this this and this
# == Generating with temperature 0.5
# This movie  this this this this this this this this this this this this this this this this this this this this now this this this this this this this this this this this this this this this this this this this this this this this this this this this this
# == Generating with temperature 1.0
# This movie this this happens this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this
# == Generating with temperature 1.5
# This movie this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this such this this this this this this back this this this this this this this this this
# 391/391 [==============================] - 139s 356ms/step - loss: 4.7077
# Epoch 6/50
# 391/391 [==============================] - ETA: 0s - loss: 4.6109== Generating with temperature 0.2
# This movie this another this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this
# == Generating with temperature 0.5
# This movie this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this
# == Generating with temperature 1.0
# This movie this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this
# == Generating with temperature 1.5
# This movie this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this
# 391/391 [==============================] - 140s 357ms/step - loss: 4.6109
# Epoch 7/50
# 391/391 [==============================] - ETA: 0s - loss: 4.5258== Generating with temperature 0.2
# This movie this this this this this is fodder this this this this this this this this this this this this like this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this
# == Generating with temperature 0.5
# This movie this this this this this this this this eric this this this this this this this this this this this this this this this this this this this this this this this this really cindy this this this this this this this this this this this this this this this
# == Generating with temperature 1.0
# This movie this this this this this this this this this this this after this this this this this this this is this this this this this this this this this this this this this this this this this this this this here is this this this this this this this this
# == Generating with temperature 1.5
# This movie compensate this this this this this this this this in this this this this this this this this this this but this this this this this this this this this this this this this this this this this this this this this this this this this this this this this
# 391/391 [==============================] - 140s 358ms/step - loss: 4.5258
# Epoch 8/50
# 391/391 [==============================] - ETA: 0s - loss: 4.4508== Generating with temperature 0.2
# This movie this class this and this this truly this wonderful this this rather this this because this this this this this this this this this this this this this this this this this this this this this this this this this this this this the this this time for this this
# == Generating with temperature 0.5
# This movie this this this this movie this this if this this this this this its this this this than this this were this this one this this this this this this this this this this this the this this this this eat this this this this this this this one aint
# == Generating with temperature 1.0
# This movie soo  this this this this this this plays plays this this plays plays this plays plays plays plays this plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays
# == Generating with temperature 1.5
# This movie this this the this poo this this this this this did this this this this this this this this this poor this this this desperate this this this this this this short this awful if this this this this this this this this nine this this this and this this
# 391/391 [==============================] - 140s 357ms/step - loss: 4.4508
# Epoch 9/50
# 391/391 [==============================] - ETA: 0s - loss: 4.3814== Generating with temperature 0.2
# This movie this this this this and this this this this when this this this this this this [UNK] this this going of this this this this this this great this this very broke this this this this this this [UNK] at this this this this this this this this more this
# == Generating with temperature 0.5
# This movie movie i in in it this she in in this this in in in in in it in in in in romania in in in in in in in in in in in in in in in in in in in in in in in in in in in in
# == Generating with temperature 1.0
# This movie this plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays plays [UNK] plays plays plays plays plays plays plays plays plays plays plays plays
# == Generating with temperature 1.5
# This movie movie this this this [UNK] this this [UNK] the this this this this did the this did this this did did this this did did the did did did this did did did did did did did did did did did did did did did did did did did did
# 391/391 [==============================] - 140s 357ms/step - loss: 4.3814
# Epoch 10/50
# 391/391 [==============================] - ETA: 0s - loss: 4.3180== Generating with temperature 0.2
# This movie sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound sound
# == Generating with temperature 0.5
# This movie up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up
# == Generating with temperature 1.0
# This movie movie this this this movie this we you alas this you bad that that this it this that movie that that it that that that that that that that that that that that that that that that that that that that that that that that that that that that that
# == Generating with temperature 1.5
# This movie this this it this in dreadful this its complete a year year its in year material year year year year year year year year year year year year year year year year year year year year year year year year year year year year year year year year year year
# 391/391 [==============================] - 140s 357ms/step - loss: 4.3180
# Epoch 11/50
# 391/391 [==============================] - ETA: 0s - loss: 4.2594== Generating with temperature 0.2
# This movie its and acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting acting
# == Generating with temperature 0.5
# This movie but but but but but but but but but but but but but but but but but but but but but but but but but but but but but but but but but but but but but goldberg but but but but but but but but but but but but
# == Generating with temperature 1.0
# This movie this you basically youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve youve
# == Generating with temperature 1.5
# This movie movie and [UNK] this this out out out out out out out out out out out out out out out out out out out out out out out out out out out out out out out out out out out out out out out out out out out out out
# 391/391 [==============================] - 140s 357ms/step - loss: 4.2594
# Epoch 12/50
# 391/391 [==============================] - ETA: 0s - loss: 4.2042== Generating with temperature 0.2
# This movie much much much much much much much much much much much much much much much much much much much much much much much much much much much much much much much much much much much much much much much much much much much much much much much much much much
# == Generating with temperature 0.5
# This movie this this this it its by by by by by by by by by by by by by by by by by by by by by by by by by by by by by by by by by by by by by by by by by by by by by
# == Generating with temperature 1.0
# This movie in in in in in in in in in in in in in in in in in in in in in in in in in in in in in that in in shows in in in in in in in in in in in in in in in in in
# == Generating with temperature 1.5
# This movie this of this this with were getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting getting
# 391/391 [==============================] - 140s 357ms/step - loss: 4.2042
# Epoch 13/50
# 391/391 [==============================] - ETA: 0s - loss: 4.1518== Generating with temperature 0.2
# This movie this this this by by by by by by by by by by by by by all by by by by by by by by by by by by by by by by by by by by by by by by by by by by by by by by by
# == Generating with temperature 0.5
# This movie white white white white white white white white white white white white white white white white white white white white white white white white white white white white white white white white white white white white white white white white white white white white white white white white white white
# == Generating with temperature 1.0
# This movie this this i [UNK] [UNK] this i i [UNK] [UNK] id [UNK] [UNK] [UNK] this which [UNK] i there [UNK] i [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] this i [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK]
# == Generating with temperature 1.5
# This movie up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up up
# 391/391 [==============================] - 140s 358ms/step - loss: 4.1518
# Epoch 14/50
# 391/391 [==============================] - ETA: 0s - loss: 3.9683== Generating with temperature 0.2
# This movie aint action action political action action action action action action action action action action action action action action action action action action action action action action action action action action our action action action action action action action action action action action action action action action action action action action
# == Generating with temperature 0.5
# This movie and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and to and and and and and and and and and and and and and and and and and
# == Generating with temperature 1.0
# This movie [UNK] treat [UNK] [UNK] [UNK] [UNK] [UNK] and and [UNK] [UNK] [UNK] [UNK] [UNK] and [UNK] [UNK] and [UNK] [UNK] and [UNK] [UNK] and and [UNK] [UNK] [UNK] [UNK] [UNK] and and [UNK] [UNK] [UNK] [UNK] and [UNK] urge [UNK] [UNK] [UNK] and [UNK] [UNK] and and [UNK] [UNK] and
# == Generating with temperature 1.5
# This movie she she she she she movie of she she she she she she she she she she she she sleeping she she she she she she and she she she she she a she of she she she actually she divine she she she she show she she she the
# 391/391 [==============================] - 140s 357ms/step - loss: 3.9683
# Epoch 15/50
# 391/391 [==============================] - ETA: 0s - loss: 3.1455== Generating with temperature 0.2
# This movie movie movie movie movie movie movie movie movie  movie movie
# == Generating with temperature 0.5
# This movie movie movie movie movie movie
# == Generating with temperature 1.0
# This movie movie movie movie movie
# == Generating with temperature 1.5
# This movie movie movie movie movie movie movie  movie movie movie
# 391/391 [==============================] - 140s 357ms/step - loss: 3.1455
# Epoch 16/50
# 391/391 [==============================] - ETA: 0s - loss: 1.5666== Generating with temperature 0.2
# This movie movie movie movie movie movie movie movie
# == Generating with temperature 0.5
# This movie movie movie movie movie movie movie movie
# == Generating with temperature 1.0
# This movie movie movie movie movie movie movie
# == Generating with temperature 1.5
# This movie movie movie movie movie movie movie movie
# 391/391 [==============================] - 140s 359ms/step - loss: 1.5666
# Epoch 17/50
# 391/391 [==============================] - ETA: 0s - loss: 1.1211== Generating with temperature 0.2
# This movie movie
# == Generating with temperature 0.5
# This movie movie
# == Generating with temperature 1.0
# This movie movie
# == Generating with temperature 1.5
# This movie movie
# 391/391 [==============================] - 140s 357ms/step - loss: 1.1211
# Epoch 18/50
# 391/391 [==============================] - ETA: 0s - loss: 0.9300== Generating with temperature 0.2
# This movie
# == Generating with temperature 0.5
# This movie
# == Generating with temperature 1.0
# This movie
# == Generating with temperature 1.5
# This movie
# 391/391 [==============================] - 140s 359ms/step - loss: 0.9300
# Epoch 19/50
# 391/391 [==============================] - ETA: 0s - loss: 0.7699== Generating with temperature 0.2
# This movie
# == Generating with temperature 0.5
# This movie
# == Generating with temperature 1.0
# This movie
# == Generating with temperature 1.5
# This movie
# 391/391 [==============================] - 140s 357ms/step - loss: 0.7699
# Epoch 20/50
# 391/391 [==============================] - ETA: 0s - loss: 0.5355== Generating with temperature 0.2
# This movie movie
# == Generating with temperature 0.5
# This movie movie
# == Generating with temperature 1.0
# This movie movie
# == Generating with temperature 1.5
# This movie movie
# 391/391 [==============================] - 140s 359ms/step - loss: 0.5355
# Epoch 21/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0986== Generating with temperature 0.2
# This movie movie
# == Generating with temperature 0.5
# This movie movie
# == Generating with temperature 1.0
# This movie movie
# == Generating with temperature 1.5
# This movie movie
# 391/391 [==============================] - 140s 357ms/step - loss: 0.0986
# Epoch 22/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0488== Generating with temperature 0.2
# This movie movie movie
# == Generating with temperature 0.5
# This movie movie
# == Generating with temperature 1.0
# This movie movie
# == Generating with temperature 1.5
# This movie movie
# 391/391 [==============================] - 140s 358ms/step - loss: 0.0488
# Epoch 23/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0454== Generating with temperature 0.2
# This movie movie movie
# == Generating with temperature 0.5
# This movie movie
# == Generating with temperature 1.0
# This movie movie
# == Generating with temperature 1.5
# This movie movie movie
# 391/391 [==============================] - 140s 357ms/step - loss: 0.0454
# Epoch 24/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0439== Generating with temperature 0.2
# This movie movie
# == Generating with temperature 0.5
# This movie movie
# == Generating with temperature 1.0
# This movie movie
# == Generating with temperature 1.5
# This movie movie
# 391/391 [==============================] - 140s 358ms/step - loss: 0.0439
# Epoch 25/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0424== Generating with temperature 0.2
# This movie movie movie
# == Generating with temperature 0.5
# This movie movie movie
# == Generating with temperature 1.0
# This movie movie
# == Generating with temperature 1.5
# This movie movie movie
# 391/391 [==============================] - 140s 359ms/step - loss: 0.0424
# Epoch 26/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0411== Generating with temperature 0.2
# This movie movie
# == Generating with temperature 0.5
# This movie movie
# == Generating with temperature 1.0
# This movie movie
# == Generating with temperature 1.5
# This movie movie
# 391/391 [==============================] - 140s 357ms/step - loss: 0.0411
# Epoch 27/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0398== Generating with temperature 0.2
# This movie movie
# == Generating with temperature 0.5
# This movie movie
# == Generating with temperature 1.0
# This movie movie
# == Generating with temperature 1.5
# This movie movie
# 391/391 [==============================] - 140s 358ms/step - loss: 0.0398
# Epoch 28/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0385== Generating with temperature 0.2
# This movie movie
# == Generating with temperature 0.5
# This movie movie movie
# == Generating with temperature 1.0
# This movie movie
# == Generating with temperature 1.5
# This movie movie
# 391/391 [==============================] - 140s 358ms/step - loss: 0.0385
# Epoch 29/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0372== Generating with temperature 0.2
# This movie movie
# == Generating with temperature 0.5
# This movie movie movie
# == Generating with temperature 1.0
# This movie movie movie
# == Generating with temperature 1.5
# This movie movie movie
# 391/391 [==============================] - 140s 358ms/step - loss: 0.0372
# Epoch 30/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0356== Generating with temperature 0.2
# This movie movie movie
# == Generating with temperature 0.5
# This movie movie movie
# == Generating with temperature 1.0
# This movie movie
# == Generating with temperature 1.5
# This movie movie movie
# 391/391 [==============================] - 140s 358ms/step - loss: 0.0356
# Epoch 31/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0341== Generating with temperature 0.2
# This movie movie movie
# == Generating with temperature 0.5
# This movie movie movie
# == Generating with temperature 1.0
# This movie movie movie
# == Generating with temperature 1.5
# This movie movie movie
# 391/391 [==============================] - 140s 357ms/step - loss: 0.0341
# Epoch 32/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0325== Generating with temperature 0.2
# This movie movie movie
# == Generating with temperature 0.5
# This movie movie movie
# == Generating with temperature 1.0
# This movie movie movie
# == Generating with temperature 1.5
# This movie movie movie
# 391/391 [==============================] - 140s 359ms/step - loss: 0.0325
# Epoch 33/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0316== Generating with temperature 0.2
# This movie movie
# == Generating with temperature 0.5
# This movie movie
# == Generating with temperature 1.0
# This movie movie movie
# == Generating with temperature 1.5
# This movie movie
# 391/391 [==============================] - 140s 357ms/step - loss: 0.0316
# Epoch 34/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0293== Generating with temperature 0.2
# This movie movie
# == Generating with temperature 0.5
# This movie movie movie
# == Generating with temperature 1.0
# This movie movie movie
# == Generating with temperature 1.5
# This movie movie
# 391/391 [==============================] - 140s 358ms/step - loss: 0.0293
# Epoch 35/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0275== Generating with temperature 0.2
# This movie movie
# == Generating with temperature 0.5
# This movie movie movie
# == Generating with temperature 1.0
# This movie movie movie
# == Generating with temperature 1.5
# This movie movie movie
# 391/391 [==============================] - 140s 357ms/step - loss: 0.0275
# Epoch 36/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0257== Generating with temperature 0.2
# This movie movie movie
# == Generating with temperature 0.5
# This movie movie movie
# == Generating with temperature 1.0
# This movie movie movie
# == Generating with temperature 1.5
# This movie movie
# 391/391 [==============================] - 140s 357ms/step - loss: 0.0257
# Epoch 37/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0240== Generating with temperature 0.2
# This movie movie movie
# == Generating with temperature 0.5
# This movie movie movie
# == Generating with temperature 1.0
# This movie movie movie
# == Generating with temperature 1.5
# This movie movie movie
# 391/391 [==============================] - 140s 358ms/step - loss: 0.0240
# Epoch 38/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0222== Generating with temperature 0.2
# This movie movie movie
# == Generating with temperature 0.5
# This movie movie movie
# == Generating with temperature 1.0
# This movie movie movie
# == Generating with temperature 1.5
# This movie movie movie
# 391/391 [==============================] - 140s 357ms/step - loss: 0.0222
# Epoch 39/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0205== Generating with temperature 0.2
# This movie movie movie
# == Generating with temperature 0.5
# This movie movie
# == Generating with temperature 1.0
# This movie movie movie
# == Generating with temperature 1.5
# This movie movie movie
# 391/391 [==============================] - 140s 358ms/step - loss: 0.0205
# Epoch 40/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0188== Generating with temperature 0.2
# This movie movie movie
# == Generating with temperature 0.5
# This movie movie
# == Generating with temperature 1.0
# This movie movie movie
# == Generating with temperature 1.5
# This movie movie movie
# 391/391 [==============================] - 140s 357ms/step - loss: 0.0188
# Epoch 41/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0174== Generating with temperature 0.2
# This movie movie
# == Generating with temperature 0.5
# This movie movie
# == Generating with temperature 1.0
# This movie movie movie
# == Generating with temperature 1.5
# This movie movie movie
# 391/391 [==============================] - 141s 359ms/step - loss: 0.0174
# Epoch 42/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0155== Generating with temperature 0.2
# This movie movie movie
# == Generating with temperature 0.5
# This movie movie
# == Generating with temperature 1.0
# This movie movie
# == Generating with temperature 1.5
# This movie movie unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic unrealistic
# 391/391 [==============================] - 140s 358ms/step - loss: 0.0155
# Epoch 43/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0139== Generating with temperature 0.2
# This movie movie movie
# == Generating with temperature 0.5
# This movie movie movie
# == Generating with temperature 1.0
# This movie movie movie
# == Generating with temperature 1.5
# This movie movie movie
# 391/391 [==============================] - 140s 359ms/step - loss: 0.0139
# Epoch 44/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0124== Generating with temperature 0.2
# This movie movie movie
# == Generating with temperature 0.5
# This movie movie movie
# == Generating with temperature 1.0
# This movie movie
# == Generating with temperature 1.5
# This movie movie movie
# 391/391 [==============================] - 140s 357ms/step - loss: 0.0124
# Epoch 45/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0110== Generating with temperature 0.2
# This movie movie
# == Generating with temperature 0.5
# This movie movie movie
# == Generating with temperature 1.0
# This movie movie movie
# == Generating with temperature 1.5
# This movie movie movie
# 391/391 [==============================] - 140s 357ms/step - loss: 0.0110
# Epoch 46/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0096== Generating with temperature 0.2
# This movie movie
# == Generating with temperature 0.5
# This movie movie
# == Generating with temperature 1.0
# This movie movie
# == Generating with temperature 1.5
# This movie movie
# 391/391 [==============================] - 140s 357ms/step - loss: 0.0096
# Epoch 47/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0084== Generating with temperature 0.2
# This movie movie movie
# == Generating with temperature 0.5
# This movie movie movie
# == Generating with temperature 1.0
# This movie movie movie
# == Generating with temperature 1.5
# This movie movie movie movie
# 391/391 [==============================] - 140s 357ms/step - loss: 0.0084
# Epoch 48/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0224== Generating with temperature 0.2
# This movie movie movie
# == Generating with temperature 0.5
# This movie movie movie
# == Generating with temperature 1.0
# This movie movie movie
# == Generating with temperature 1.5
# This movie movie movie
# 391/391 [==============================] - 141s 359ms/step - loss: 0.0224
# Epoch 49/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0066== Generating with temperature 0.2
# This movie movie
# == Generating with temperature 0.5
# This movie movie
# == Generating with temperature 1.0
# This movie movie
# == Generating with temperature 1.5
# This movie movie
# 391/391 [==============================] - 140s 358ms/step - loss: 0.0066
# Epoch 50/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0054== Generating with temperature 0.2
# This movie movie movie
# == Generating with temperature 0.5
# This movie movie movie
# == Generating with temperature 1.0
# This movie movie
# == Generating with temperature 1.5
# This movie movie
# 391/391 [==============================] - 141s 360ms/step - loss: 0.0054

# %% [markdown]
# ## Conclusion
# As the resource was limited and I could only use GPU for very short time the result was not as expected as it should have been. I also ran the model for only 50 epochs that is why output are not as expected from the model.
